# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset("tips")
sns.catplot(x="day", y ="total_bill", kind="box", data=tips)
plt.show()

# %%
sns.catplot(x="day", y ="total_bill", hue="smoker", kind="box", data=tips)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Create a new 'Weekend' column
tips["Weekend"] = tips["day"].isin(["Saturday", "Sunday"])

# Create a categorical box plot with dodge set to False
sns.catplot(x="day", y="total_bill", hue="Weekend", kind="box", dodge=False, data=tips)

# Show the plot
plt.show()

# %%
diamonds=sns.load_dataset("diamonds")
sns.catplot(x="color", y="price", kind="boxen", data=diamonds.sort_values("color"))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a dataset
data = sns.load_dataset("tips")

# Create a violin plot
sns.violinplot(x="total_bill", y="day", hue="time", data=tips)

# Show the plot
plt.show()

# %%
# Create a violin plot
sns.violinplot(x="total_bill", y="day", hue="time", bw=.15, cut=0, data=tips)

# Show the plot
plt.show()

# %%
# Create a violin plot
sns.violinplot(x="day", y="total_bill", hue="time", split=True, data=tips)

# Show the plot
plt.show()

# %%
# Create a violin plot
sns.violinplot(x="day", y="total_bill", hue="time",inner="stick", palette="pastel", split=True, data=tips)


# Show the plot
plt.show()
